# %% [raw]
# ---
# title: "The return of the big bad inflation?"
# format:
#     revealjs:
#         navigation-mode: grid
# ---

# %% [markdown]
# # Is Inflation Coming back?
#
# ##
#
# <!-- ```{python}
# import altair as alt
# import dbnomics
# import pandas as pd
# df = dbnomics.fetch_series(["ECB/ICP/M.U2.N.PCCI00.3.3MM","OECD/MEI/USA.CPALTT01.CTGY.M"])
# df = df[["period", "value", "series_code"]]
# df['series'] = df['series_code'].replace({"USA.CPALTT01.CTGY.M": "USA", "M.U2.N.PCCI00.3.3MM": "EZ"})
# df.dropna()
# alt.Chart(df).mark_line().encode(x="period", y="value", color="series")
# ``` -->
#
# ##

# %%
import altair as alt
import dbnomics
import pandas as pd
df = dbnomics.fetch_series(["M.FR.PCPI_PC_CP_A_PT","M.GB.PCPI_PC_CP_A_PT", "M.US.PCPI_PC_CP_A_PT"])
df = df[["period", "value", "series_code"]]
df['series'] = df['series_code'].replace({"USA.CPALTT01.CTGY.M": "USA", "M.U2.N.PCCI00.3.3MM": "EZ"})
df.dropna()
alt.Chart(df).mark_line().encode(x="period", y="value", color="series")

# %% [markdown]
# ![Inflation Eurozone](assets/alt_inflation.png)
#
#
# ## Emerging / Developped Markets  {auto-animate="true"}
#
# ![World Inflation Outlook (2022)](assets/world_inflation_outlook_2022.png)
#
# ## Emerging / Developped Markets  {auto-animate="true"}
#
# ::: columns
# :::: column
# ![World Inflation Outlook (2013)](assets/world_inflation_outlook_2013.png)
# ::::
# :::: column
# ![World Inflation Outlook (2022)](assets/world_inflation_outlook_2022.png)
# ::::
# :::
#
# . . .
#
# - Inflation has never disappeared from the world
# - The problem is quite different in developped and emerging countries
#
# # Crazy ideas
#
# What comes to mind?
#
# - inflation tax
#     - in many countries central banks are not that independent
#
# # Check
#
# ::: columns
#
# :::: column
#
# - First List
#
# ::::
#
# :::: column
#
# - Second List
# - Not
#
# ::::
#
# :::: column
#
# ::::
#
# :::
#
#
# # The sources of Inflation
#
#
# ## Demand-pull shocks
#
# ## Cost-push shocks
#
# ## Inflation expectations
#
#
# ## Reminder: AS/AD model
#
# chocs:
# ukraine
# covid
#
# Which prices are rising?
#
# https://www.ecb.europa.eu/stats/macroeconomic_and_sectoral/hicp/html/index.en.html
#
# - Food, Beverage
# - Housing, Electricity, Gaz, ...
# Household Equipement
#
#
# First time ECB is dealing with high inflation
